# %%
import importlib
import pandas as pd
import numpy as np
import os
import mysql.connector
from dotenv import load_dotenv
import constants
importlib.reload(constants)
from constants import DB_DRIVER_NAMES, DB_DRIVER_TO_API_NAME, API_RACE_NAMES
import pprint
import xgboost as xg
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv('all_race_data.csv')
print(df)
# Out:
#        year             race_name  lap_number       driver_id  position  \
# 0      2023    Bahrain Grand Prix           1  max_verstappen         1
# 1      2023    Bahrain Grand Prix           1         leclerc         2
# 2      2023    Bahrain Grand Prix           1           perez         3
# 3      2023    Bahrain Grand Prix           1           sainz         4
# 4      2023    Bahrain Grand Prix           1        hamilton         5
# ...     ...                   ...         ...             ...       ...
# 47743  2024  São Paulo Grand Prix          69           perez        11
# 47744  2024  São Paulo Grand Prix          69         bearman        12
# 47745  2024  São Paulo Grand Prix          69          bottas        13
# 47746  2024  São Paulo Grand Prix          69          alonso        14
# 47747  2024  São Paulo Grand Prix          69            zhou        15
#
#        lap_time
# 0        99.019
# 1       100.230
# 2       101.063
# 3       101.659
# 4       102.288
# ...         ...
# 47743    82.222
# 47744    82.839
# 47745    83.003
# 47746    83.919
# 47747    83.701
#
# [47748 rows x 6 columns]

# %%
#Finds the Lap time change between lap x and lap x + 1
#Removes outliers like pit stops and saftey cars/VSC
def get_lap_time_change(driver, year, race, stops):
    driver_race_2024_df = (df[(df.race_name == f"{race}") & (df.driver_id == f"{driver}") & (df.year == year)])
    if driver_race_2024_df.empty:
        return None
    total_time = 0
    time_changes = []
    prev_lap = driver_race_2024_df.iloc[0, 5]
    for index, row in driver_race_2024_df.iterrows():
        total_time += row['lap_time']
        time_change = prev_lap - row['lap_time']
        if (-9 < time_change < 6):
            time_changes.append(time_change)
        prev_lap = row['lap_time']
    avg_time_change = sum(time_changes) / (len(time_changes) + 1)
    return avg_time_change

# %%
def api_name_to_db_name(race_name):
    race_name_map = {
        "Bahrain Grand Prix": "bahrain",
        "Saudi Arabian Grand Prix": "saudi-arabia",
        "Australian Grand Prix": "australia",
        "Japanese Grand Prix": "japan",
        "Chinese Grand Prix": "china",
        "Miami Grand Prix": "miami",
        "Emilia Romagna Grand Prix": "emilia-romagna",
        "Monaco Grand Prix": "monaco",
        "Canadian Grand Prix": "canada",
        "Spanish Grand Prix": "spain",
        "Austrian Grand Prix": "austria",
        "British Grand Prix": "great-britain",
        "Hungarian Grand Prix": "hungary",
        "Belgian Grand Prix": "belgium",
        "Dutch Grand Prix": "netherlands",
        "Italian Grand Prix": "italy",
        "Azerbaijan Grand Prix": "azerbaijan",
        "Singapore Grand Prix": "singapore",
        "United States Grand Prix": "united-states",
        "Mexico City Grand Prix": "mexico",
        "São Paulo Grand Prix": "sao-paulo",
        "Las Vegas Grand Prix": "las-vegas",
        "Qatar Grand Prix": "qatar",
        "Abu Dhabi Grand Prix": "abu-dhabi",
        "French Grand Prix" : "france"
    }
    return race_name_map.get(race_name, f"Error: '{race_name}' not found.")

# %%
load_dotenv()

db_host = os.getenv('DB_HOST')
db_user = os.getenv('DB_USER')
db_password = os.getenv('DB_PASSWORD')
db_name = os.getenv('DB_NAME')

# %%
#Finds the number of pit stops a driver completed per race
def find_number_pits(driver, year, race):
    connection = mysql.connector.connect(
        host=db_host,
        user =db_user,
        password = db_password,
        database = db_name,
        use_pure=True,
        ssl_disabled=True
    )

    mycursor = connection.cursor()

    mycursor.execute(f"select id from race where grand_prix_id = '{race}' and year = '{year}'")
    race_id_result = mycursor.fetchall()
    if len(race_id_result) == 0:
        return None
    race_id = race_id_result[0][0]
    mycursor.execute(f"select pit_stops from race_result where race_id = '{race_id}' and driver_id = '{driver}'")
    pit_stops_tuple = mycursor.fetchall()
    if len(pit_stops_tuple) == 0:
        return None
    pit_stops = pit_stops_tuple[0][0]
    return pit_stops

# %%
#Finds the race data, including lap times and pit stops for each driver.
def get_race_pace_data():
    race_pace_data = {}
    for year in [2023, 2024]:
        for race in API_RACE_NAMES:
            race_data = []
            for driver in DB_DRIVER_NAMES:
                db_race_name = api_name_to_db_name(race)
                api_driver_name = DB_DRIVER_TO_API_NAME(driver)
                stops = find_number_pits(driver, year, db_race_name)
                avg_time_change = get_lap_time_change(api_driver_name, year, race, stops)
                if avg_time_change is not None:
                    race_data.append({
                        "driver": driver,
                        "avg_time_change": avg_time_change,
                        "stops": stops
                    })
            race_pace_data[f"{year} {race}"] = race_data
    return race_pace_data

# %%
total_data = get_race_pace_data()
pprint.pprint(total_data)
# Out:
# {'2023 Abu Dhabi Grand Prix': [{'avg_time_change': -0.0202452830188678,
#                                 'driver': 'carlos-sainz-jr',
#                                 'stops': 2},
#                                {'avg_time_change': -0.0077115384615383895,
#                                 'driver': 'charles-leclerc',
#                                 'stops': 2},
#                                {'avg_time_change': -0.06531372549019614,
#                                 'driver': 'alexander-albon',
#                                 'stops': 2},
#                                {'avg_time_change': -0.049431372549019345,
#                                 'driver': 'daniel-ricciardo',
#                                 'stops': 2},
#                                {'avg_time_change': 0.020019230769230435,
#                                 'driver': 'fernando-alonso',
#                                 'stops': 2},
#                                {'avg_time_change': 0.0113653846153845,
#                                 'driver': 'george-russell',
#                                 'stops': 2},
#                                {'avg_time_change': -0.09813725490196097,
#                                 'driver': 'guanyu-zhou',
#                                 'stops': 2},
#                                {'avg_time_change': -0.06882352941176509,
#                                 'driver': 'kevin-magnussen',
#                                 'stops': 2},
#                                {'avg_time_change': -0.07150980392156901,
#                                 'driver': 'lance-stroll',
#                                 'stops': 2},
#                                {'avg_time_change': 0.00773076923076925,
#                                 'driver': 'lando-norris',
#                                 'stops': 2},
#                                {'avg_time_change': 0.06336538461538464,
#                                 'driver': 'lewis-hamilton',
#                                 'stops': 2},
#                                {'avg_time_change': -0.07864705882352961,
#                                 'driver': 'logan-sargeant',
#                                 'stops': 2},
#                                {'avg_time_change': -0.053846153846154335,
#                                 'driver': 'max-verstappen',
#                                 'stops': 2},
#                                {'avg_time_change': -0.04309803921568586,
#                                 'driver': 'nico-hulkenberg',
#                                 'stops': 2},
#                                {'avg_time_change': -0.011942307692307325,
#                                 'driver': 'oscar-piastri',
#                                 'stops': 2},
#                                {'avg_time_change': -0.015230769230769535,
#                                 'driver': 'pierre-gasly',
#                                 'stops': 2},
#                                {'avg_time_change': -0.07590196078431391,
#                                 'driver': 'sergio-perez',
#                                 'stops': 2},
#                                {'avg_time_change': -0.010301886792452685,
#                                 'driver': 'valtteri-bottas',
#                                 'stops': 1},
#                                {'avg_time_change': 0.0726851851851854,
#                                 'driver': 'yuki-tsunoda',
#                                 'stops': 1},
#                                {'avg_time_change': -0.03792452830188689,
#                                 'driver': 'esteban-ocon',
#                                 'stops': 1}],
#  '2023 Australian Grand Prix': [{'avg_time_change': 0.23786666666666684,
#                                  'driver': 'carlos-sainz-jr',
#                                  'stops': 4},
#                                 {'avg_time_change': 0.4842000000000013,
#                                  'driver': 'alexander-albon',
#                                  'stops': 0},
#                                 {'avg_time_change': 0.230326086956522,
#                                  'driver': 'fernando-alonso',
#                                  'stops': 3},
#                                 {'avg_time_change': 0.7085454545454556,
#                                  'driver': 'george-russell',
#                                  'stops': 2},
#                                 {'avg_time_change': -0.10779545454545379,
#                                  'driver': 'guanyu-zhou',
#                                  'stops': 5},
#                                 {'avg_time_change': 0.20316279069767418,
#                                  'driver': 'kevin-magnussen',
#                                  'stops': 2},
#                                 {'avg_time_change': 0.2905333333333333,
#                                  'driver': 'lance-stroll',
#                                  'stops': 3},
#                                 {'avg_time_change': 0.31164444444444445,
#                                  'driver': 'lando-norris',
#                                  'stops': 3},
#                                 {'avg_time_change': 0.04253333333333368,
#                                  'driver': 'lewis-hamilton',
#                                  'stops': 3},
#                                 {'avg_time_change': 0.2080243902439027,
#                                  'driver': 'logan-sargeant',
#                                  'stops': 6},
#                                 {'avg_time_change': 0.11980434782608625,
#                                  'driver': 'max-verstappen',
#                                  'stops': 3},
#                                 {'avg_time_change': 0.3254888888888887,
#                                  'driver': 'nico-hulkenberg',
#                                  'stops': 3},
#                                 {'avg_time_change': -0.0037777777777775,
#                                  'driver': 'oscar-piastri',
#                                  'stops': 4},
#                                 {'avg_time_change': 0.3610000000000005,
#                                  'driver': 'pierre-gasly',
#                                  'stops': 2},
#                                 {'avg_time_change': 0.18206818181818238,
#                                  'driver': 'sergio-perez',
#                                  'stops': 5},
#                                 {'avg_time_change': -0.04069767441860498,
#                                  'driver': 'valtteri-bottas',
#                                  'stops': 6},
#                                 {'avg_time_change': 0.34163636363636324,
#                                  'driver': 'yuki-tsunoda',
#                                  'stops': 4},
#                                 {'avg_time_change': 0.09655555555555585,
#                                  'driver': 'esteban-ocon',
#                                  'stops': 3}],
#  '2023 Austrian Grand Prix': [{'avg_time_change': -0.3116615384615386,
#                                'driver': 'carlos-sainz-jr',
#                                'stops': 3},
#                               {'avg_time_change': -0.21725757575757573,
#                                'driver': 'charles-leclerc',
#                                'stops': 3},
#                               {'avg_time_change': 0.04103076923076925,
#                                'driver': 'alexander-albon',
#                                'stops': 3},
#                               {'avg_time_change': -0.13137878787878776,
#                                'driver': 'fernando-alonso',
#                                'stops': 3},
#                               {'avg_time_change': -0.04782812499999989,
#                                'driver': 'george-russell',
#                                'stops': 3},
#                               {'avg_time_change': -0.19958064516129023,
#                                'driver': 'guanyu-zhou',
#                                'stops': 3},
#                               {'avg_time_change': -0.08023809523809512,
#                                'driver': 'kevin-magnussen',
#                                'stops': 3},
#                               {'avg_time_change': -0.24668253968253964,
#                                'driver': 'lance-stroll',
#                                'stops': 4},
#                               {'avg_time_change': -0.24034848484848484,
#                                'driver': 'lando-norris',
#                                'stops': 3},
#                               {'avg_time_change': -0.19451515151515164,
#                                'driver': 'lewis-hamilton',
#                                'stops': 3},
#                               {'avg_time_change': -0.0815873015873016,
#                                'driver': 'logan-sargeant',
#                                'stops': 3},
#                               {'avg_time_change': -0.2633666666666665,
#                                'driver': 'max-verstappen',
#                                'stops': 4},
#                               {'avg_time_change': -0.3198999999999998,
#                                'driver': 'nico-hulkenberg',
#                                'stops': 2},
#                               {'avg_time_change': -0.14454098360655726,
#                                'driver': 'oscar-piastri',
#                                'stops': 4},
#                               {'avg_time_change': 0.006323076923076944,
#                                'driver': 'pierre-gasly',
#                                'stops': 3},
#                               {'avg_time_change': -0.20566666666666655,
#                                'driver': 'sergio-perez',
#                                'stops': 3},
#                               {'avg_time_change': -0.07177049180327869,
#                                'driver': 'valtteri-bottas',
#                                'stops': 3},
#                               {'avg_time_change': -0.15972131147541,
#                                'driver': 'yuki-tsunoda',
#                                'stops': 4},
#                               {'avg_time_change': -0.0500793650793651,
#                                'driver': 'esteban-ocon',
#                                'stops': 3}],
#  '2023 Azerbaijan Grand Prix': [{'avg_time_change': 0.22922448979591806,
#                                  'driver': 'carlos-sainz-jr',
#                                  'stops': 1},
#                                 {'avg_time_change': 0.12868749999999954,
#                                  'driver': 'charles-leclerc',
#                                  'stops': 1},
#                                 {'avg_time_change': 0.07700000000000012,
#                                  'driver': 'alexander-albon',
#                                  'stops': 1},
#                                 {'avg_time_change': 0.29020408163265304,
#                                  'driver': 'fernando-alonso',
#                                  'stops': 1},
#                                 {'avg_time_change': 0.01600000000000009,
#                                  'driver': 'george-russell',
#                                  'stops': 2},
#                                 {'avg_time_change': 0.21329411764705952,
#                                  'driver': 'guanyu-zhou',
#                                  'stops': 1},
#                                 {'avg_time_change': 0.1719347826086958,
#                                  'driver': 'kevin-magnussen',
#                                  'stops': 1},
#                                 {'avg_time_change': 0.17233333333333345,
#                                  'driver': 'lance-stroll',
#                                  'stops': 1},
#                                 {'avg_time_change': 0.03934782608695657,
#                                  'driver': 'lando-norris',
#                                  'stops': 1},
#                                 {'avg_time_change': 0.19810416666666697,
#                                  'driver': 'lewis-hamilton',
#                                  'stops': 1},
#                                 {'avg_time_change': 0.13750000000000037,
#                                  'driver': 'logan-sargeant',
#                                  'stops': 1},
#                                 {'avg_time_change': 0.049625000000000107,
#                                  'driver': 'max-verstappen',
#                                  'stops': 1},
#                                 {'avg_time_change': -0.15642222222222193,
#                                  'driver': 'nico-hulkenberg',
#                                  'stops': 1},
#                                 {'avg_time_change': 0.19567391304347806,
#                                  'driver': 'oscar-piastri',
#                                  'stops': 1},
#                                 {'avg_time_change': -0.04678571428571437,
#                                  'driver': 'pierre-gasly',
#                                  'stops': 2},
#                                 {'avg_time_change': 0.11125000000000007,
#                                  'driver': 'sergio-perez',
#                                  'stops': 1},
#                                 {'avg_time_change': -0.2591428571428575,
#                                  'driver': 'valtteri-bottas',
#                                  'stops': 3},
#                                 {'avg_time_change': 0.06288888888888854,
#                                  'driver': 'yuki-tsunoda',
#                                  'stops': 1},
#                                 {'avg_time_change': 0.016510638297872565,
#                                  'driver': 'esteban-ocon',
#                                  'stops': 1}],
#  '2023 Bahrain Grand Prix': [{'avg_time_change': -0.10817307692307693,
#                               'driver': 'carlos-sainz-jr',
#                               'stops': 2},
#                              {'avg_time_change': -0.10827777777777767,
#                               'driver': 'charles-leclerc',
#                               'stops': 2},
#                              {'avg_time_change': -0.18495999999999982,
#                               'driver': 'alexander-albon',
#                               'stops': 3},
#                              {'avg_time_change': -0.0683653846153842,
#                               'driver': 'fernando-alonso',
#                               'stops': 2},
#                              {'avg_time_change': -0.13846153846153825,
#                               'driver': 'george-russell',
#                               'stops': 2},
#                              {'avg_time_change': -0.16631250000000009,
#                               'driver': 'guanyu-zhou',
#                               'stops': 3},
#                              {'avg_time_change': -0.2817999999999998,
#                               'driver': 'kevin-magnussen',
#                               'stops': 3},
#                              {'avg_time_change': -0.08065384615384566,
#                               'driver': 'lance-stroll',
#                               'stops': 2},
#                              {'avg_time_change': -0.2494186046511633,
#                               'driver': 'lando-norris',
#                               'stops': 6},
#                              {'avg_time_change': -0.0969230769230765,
#                               'driver': 'lewis-hamilton',
#                               'stops': 2},
#                              {'avg_time_change': -0.2317551020408165,
#                               'driver': 'logan-sargeant',
#                               'stops': 3},
#                              {'avg_time_change': -0.10915686274509791,
#                               'driver': 'max-verstappen',
#                               'stops': 2},
#                              {'avg_time_change': -0.39948000000000033,
#                               'driver': 'nico-hulkenberg',
#                               'stops': 3},
#                              {'avg_time_change': -0.0271666666666673,
#                               'driver': 'oscar-piastri',
#                               'stops': 0},
#                              {'avg_time_change': -0.20352000000000003,
#                               'driver': 'pierre-gasly',
#                               'stops': 3},
#                              {'avg_time_change': -0.009980769230769609,
#                               'driver': 'sergio-perez',
#                               'stops': 2},
#                              {'avg_time_change': -0.1785769230769231,
#                               'driver': 'valtteri-bottas',
#                               'stops': 2},
#                              {'avg_time_change': -0.16399999999999978,
#                               'driver': 'yuki-tsunoda',
#                               'stops': 3},
#                              {'avg_time_change': -0.2140000000000003,
#                               'driver': 'esteban-ocon',
#                               'stops': 3}],
#  '2023 Belgian Grand Prix': [{'avg_time_change': -0.8370869565217391,
#                               'driver': 'carlos-sainz-jr',
#                               'stops': 1},
#                              {'avg_time_change': -0.6183488372093023,
#                               'driver': 'charles-leclerc',
#                               'stops': 2},
#                              {'avg_time_change': -0.8978048780487808,
#                               'driver': 'alexander-albon',
#                               'stops': 3},
#                              {'avg_time_change': -0.7112439024390245,
#                               'driver': 'daniel-ricciardo',
#                               'stops': 2},
#                              {'avg_time_change': -0.3256097560975612,
#                               'driver': 'fernando-alonso',
#                               'stops': 2},
#                              {'avg_time_change': -0.21881395348837224,
#                               'driver': 'george-russell',
#                               'stops': 1},
#                              {'avg_time_change': -0.49840476190476174,
#                               'driver': 'guanyu-zhou',
#                               'stops': 2},
#                              {'avg_time_change': -0.6829756097560975,
#                               'driver': 'kevin-magnussen',
#                               'stops': 2},
#                              {'avg_time_change': 0.0048571428571430415,
#                               'driver': 'lance-stroll',
#                               'stops': 1},
#                              {'avg_time_change': -0.5721190476190479,
#                               'driver': 'lando-norris',
#                               'stops': 2},
#                              {'avg_time_change': -0.6741707317073172,
#                               'driver': 'lewis-hamilton',
#                               'stops': 3},
#                              {'avg_time_change': -0.9322249999999996,
#                               'driver': 'logan-sargeant',
#                               'stops': 3},
#                              {'avg_time_change': -0.5319302325581393,
#                               'driver': 'max-verstappen',
#                               'stops': 2},
#                              {'avg_time_change': -0.5404250000000002,
#                               'driver': 'nico-hulkenberg',
#                               'stops': 2},
#                              {'avg_time_change': -0.36907142857142866,
#                               'driver': 'pierre-gasly',
#                               'stops': 1},
#                              {'avg_time_change': -0.6290232558139536,
#                               'driver': 'sergio-perez',
#                               'stops': 2},
#                              {'avg_time_change': -0.4576666666666669,
#                               'driver': 'valtteri-bottas',
#                               'stops': 2},
#                              {'avg_time_change': -0.5450952380952379,
#                               'driver': 'yuki-tsunoda',
#                               'stops': 2},
#                              {'avg_time_change': -0.6072195121951219,
#                               'driver': 'esteban-ocon',
#                               'stops': 2}],
#  '2023 British Grand Prix': [{'avg_time_change': 0.0807173913043477,
#                               'driver': 'carlos-sainz-jr',
#                               'stops': 1},
#                              {'avg_time_change': 0.011956521739130373,
#                               'driver': 'charles-leclerc',
#                               'stops': 2},
#                              {'avg_time_change': -0.0853404255319145,
#                               'driver': 'alexander-albon',
#                               'stops': 1},
#                              {'avg_time_change': 0.0819387755102038,
#                               'driver': 'fernando-alonso',
#                               'stops': 1},
#                              {'avg_time_change': 0.05687499999999979,
#                               'driver': 'george-russell',
#                               'stops': 1},
#                              {'avg_time_change': -0.11458139534883736,
#                               'driver': 'guanyu-zhou',
#                               'stops': 3},
#                              {'avg_time_change': 0.09267741935483886,
#                               'driver': 'kevin-magnussen',
#                               'stops': 0},
#                              {'avg_time_change': 0.17216666666666658,
#                               'driver': 'lance-stroll',
#                               'stops': 1},
#                              {'avg_time_change': 0.21095918367346944,
#                               'driver': 'lando-norris',
#                               'stops': 1},
#                              {'avg_time_change': 0.21438775510204158,
#                               'driver': 'lewis-hamilton',
#                               'stops': 1},
#                              {'avg_time_change': 0.2382222222222222,
#                               'driver': 'logan-sargeant',
#                               'stops': 1},
#                              {'avg_time_change': 0.21279591836734738,
#                               'driver': 'max-verstappen',
#                               'stops': 1},
#                              {'avg_time_change': -0.0749302325581394,
#                               'driver': 'nico-hulkenberg',
#                               'stops': 2},
#                              {'avg_time_change': 0.007187499999999976,
#                               'driver': 'oscar-piastri',
#                               'stops': 1},
#                              {'avg_time_change': -0.23407317073170716,
#                               'driver': 'pierre-gasly',
#                               'stops': 1},
#                              {'avg_time_change': 0.0793555555555552,
#                               'driver': 'sergio-perez',
#                               'stops': 1},
#                              {'avg_time_change': 0.09528888888888881,
#                               'driver': 'valtteri-bottas',
#                               'stops': 1},
#                              {'avg_time_change': 0.039209302325581556,
#                               'driver': 'yuki-tsunoda',
#                               'stops': 2},
#                              {'avg_time_change': 0.15377777777777782,
#                               'driver': 'esteban-ocon',
#                               'stops': 0}],
#  '2023 Canadian Grand Prix': [{'avg_time_change': 0.06649999999999992,
#                                'driver': 'carlos-sainz-jr',
#                                'stops': 1},
#                               {'avg_time_change': 0.07863333333333315,
#                                'driver': 'charles-leclerc',
#                                'stops': 1},
#                               {'avg_time_change': 0.02057142857142845,
#                                'driver': 'alexander-albon',
#                                'stops': 1},
#                               {'avg_time_change': 0.08078333333333347,
#                                'driver': 'fernando-alonso',
#                                'stops': 2},
#                               {'avg_time_change': 0.09700000000000025,
#                                'driver': 'george-russell',
#                                'stops': 1},
#                               {'avg_time_change': -0.1413064516129034,
#                                'driver': 'guanyu-zhou',
#                                'stops': 2},
#                               {'avg_time_change': 0.20507017543859662,
#                                'driver': 'kevin-magnussen',
#                                'stops': 2},
#                               {'avg_time_change': -0.12870967741935468,
#                                'driver': 'lance-stroll',
#                                'stops': 2},
#                               {'avg_time_change': 0.027540983606557257,
#                                'driver': 'lando-norris',
#                                'stops': 2},
#                               {'avg_time_change': 0.15622950819672157,
#                                'driver': 'lewis-hamilton',
#                                'stops': 2},
#                               {'avg_time_change': 0.274666666666666,
#                                'driver': 'logan-sargeant',
#                                'stops': 0},
#                               {'avg_time_change': 0.14662295081967242,
#                                'driver': 'max-verstappen',
#                                'stops': 2},
#                               {'avg_time_change': -0.1400327868852457,
#                                'driver': 'nico-hulkenberg',
#                                'stops': 2},
#                               {'avg_time_change': 0.19942622950819658,
#                                'driver': 'oscar-piastri',
#                                'stops': 2},
#                               {'avg_time_change': -0.02693333333333309,
#                                'driver': 'pierre-gasly',
#                                'stops': 2},
#                               {'avg_time_change': 0.06691228070175426,
#                                'driver': 'sergio-perez',
#                                'stops': 2},
#                               {'avg_time_change': 0.06574999999999989,
#                                'driver': 'valtteri-bottas',
#                                'stops': 1},
#                               {'avg_time_change': -0.019419354838709574,
#                                'driver': 'yuki-tsunoda',
#                                'stops': 2},
#                               {'avg_time_change': 0.09361666666666627,
#                                'driver': 'esteban-ocon',
#                                'stops': 2}],
#  '2023 Chinese Grand Prix': [],
#  '2023 Dutch Grand Prix': [{'avg_time_change': -0.201767857142857,
#                             'driver': 'carlos-sainz-jr',
#                             'stops': 5},
#                            {'avg_time_change': -0.24693750000000003,
#                             'driver': 'charles-leclerc',
#                             'stops': 2},
#                            {'avg_time_change': 0.06829824561403534,
#                             'driver': 'alexander-albon',
#                             'stops': 4},
#                            {'avg_time_change': 0.16889090909090912,
#                             'driver': 'fernando-alonso',
#                             'stops': 5},
#                            {'avg_time_change': -0.017089285714285855,
#                             'driver': 'george-russell',
#                             'stops': 7},
#                            {'avg_time_change': -0.3425098039215687,
#                             'driver': 'guanyu-zhou',
#                             'stops': 4},
#                            {'avg_time_change': -0.1916491228070169,
#                             'driver': 'kevin-magnussen',
#                             'stops': 6},
#                            {'avg_time_change': -0.12594230769230755,
#                             'driver': 'lance-stroll',
#                             'stops': 7},
#                            {'avg_time_change': -0.3433392857142858,
#                             'driver': 'lando-norris',
#                             'stops': 6},
#                            {'avg_time_change': -0.10858490566037728,
#                             'driver': 'lewis-hamilton',
#                             'stops': 5},
#                            {'avg_time_change': -0.21324137931034498,
#                             'driver': 'liam-lawson',
#                             'stops': 7},
#                            {'avg_time_change': 2.163,
#                             'driver': 'logan-sargeant',
#                             'stops': 0},
#                            {'avg_time_change': 0.031218181818182054,
#                             'driver': 'max-verstappen',
#                             'stops': 6},
#                            {'avg_time_change': 0.3057962962962964,
#                             'driver': 'nico-hulkenberg',
#                             'stops': 5},
#                            {'avg_time_change': 0.24468518518518506,
#                             'driver': 'oscar-piastri',
#                             'stops': 5},
#                            {'avg_time_change': -0.3118909090909088,
#                             'driver': 'pierre-gasly',
#                             'stops': 5},
#                            {'avg_time_change': -0.26564285714285696,
#                             'driver': 'sergio-perez',
#                             'stops': 6},
#                            {'avg_time_change': 0.2374363636363641,
#                             'driver': 'valtteri-bottas',
#                             'stops': 5},
#                            {'avg_time_change': -0.1422542372881356,
#                             'driver': 'yuki-tsunoda',
#                             'stops': 5},
#                            {'avg_time_change': -0.12116071428571448,
#                             'driver': 'esteban-ocon',
#                             'stops': 6}],
#  '2023 Emilia Romagna Grand Prix': [],
#  '2023 Hungarian Grand Prix': [{'avg_time_change': -0.012626865671641634,
#                                 'driver': 'carlos-sainz-jr',
#                                 'stops': 2},
#                                {'avg_time_change': 0.011358208955224028,
#                                 'driver': 'charles-leclerc',
#                                 'stops': 2},
#                                {'avg_time_change': -0.03570769230769206,
#                                 'driver': 'alexander-albon',
#                                 'stops': 2},
#                                {'avg_time_change': -0.11770769230769247,
#                                 'driver': 'daniel-ricciardo',
#                                 'stops': 2},
#                                {'avg_time_change': 0.031477611940298425,
#                                 'driver': 'fernando-alonso',
#                                 'stops': 2},
#                                {'avg_time_change': -0.08572727272727275,
#                                 'driver': 'george-russell',
#                                 'stops': 2},
#                                {'avg_time_change': -0.08769230769230774,
#                                 'driver': 'guanyu-zhou',
#                                 'stops': 2},
#                                {'avg_time_change': -0.08920000000000025,
#                                 'driver': 'kevin-magnussen',
#                                 'stops': 2},
#                                {'avg_time_change': -0.09587692307692329,
#                                 'driver': 'lance-stroll',
#                                 'stops': 2},
#                                {'avg_time_change': -0.022925373134328166,
#                                 'driver': 'lando-norris',
#                                 'stops': 2},
#                                {'avg_time_change': 0.010134328358208987,
#                                 'driver': 'lewis-hamilton',
#                                 'stops': 2},
#                                {'avg_time_change': -0.0890806451612905,
#                                 'driver': 'logan-sargeant',
#                                 'stops': 2},
#                                {'avg_time_change': -0.05077611940298509,
#                                 'driver': 'max-verstappen',
#                                 'stops': 2},
#                                {'avg_time_change': -0.08315384615384595,
#                                 'driver': 'nico-hulkenberg',
#                                 'stops': 2},
#                                {'avg_time_change': -0.03498507462686579,
#                                 'driver': 'oscar-piastri',
#                                 'stops': 2},
#                                {'avg_time_change': 0.0,
#                                 'driver': 'pierre-gasly',
#                                 'stops': 0},
#                                {'avg_time_change': -0.07550000000000028,
#                                 'driver': 'sergio-perez',
#                                 'stops': 2},
#                                {'avg_time_change': -0.10107692307692297,
#                                 'driver': 'valtteri-bottas',
#                                 'stops': 2},
#                                {'avg_time_change': -0.12515384615384623,
#                                 'driver': 'yuki-tsunoda',
#                                 'stops': 2},
#                                {'avg_time_change': 1.928000000000002,
#                                 'driver': 'esteban-ocon',
#                                 'stops': 0}],
#  '2023 Italian Grand Prix': [{'avg_time_change': -0.11385999999999996,
#                               'driver': 'carlos-sainz-jr',
#                               'stops': 1},
#                              {'avg_time_change': -0.06882000000000005,
#                               'driver': 'charles-leclerc',
#                               'stops': 1},
#                              {'avg_time_change': -0.0372399999999999,
#                               'driver': 'alexander-albon',
#                               'stops': 1},
#                              {'avg_time_change': 0.008340000000000316,
#                               'driver': 'fernando-alonso',
#                               'stops': 1},
#                              {'avg_time_change': -0.05436000000000007,
#                               'driver': 'george-russell',
#                               'stops': 1},
#                              {'avg_time_change': -0.22561702127659572,
#                               'driver': 'guanyu-zhou',
#                               'stops': 2},
#                              {'avg_time_change': -0.21808695652173907,
#                               'driver': 'kevin-magnussen',
#                               'stops': 2},
#                              {'avg_time_change': -0.16726530612244864,
#                               'driver': 'lance-stroll',
#                               'stops': 1},
#                              {'avg_time_change': -0.02829999999999984,
#                               'driver': 'lando-norris',
#                               'stops': 1},
#                              {'avg_time_change': -0.034560000000000174,
#                               'driver': 'lewis-hamilton',
#                               'stops': 1},
#                              {'avg_time_change': -0.06560416666666669,
#                               'driver': 'liam-lawson',
#                               'stops': 2},
#                              {'avg_time_change': -0.15877551020408165,
#                               'driver': 'logan-sargeant',
#                               'stops': 1},
#                              {'avg_time_change': -0.09168000000000007,
#                               'driver': 'max-verstappen',
#                               'stops': 1},
#                              {'avg_time_change': -0.10538297872340462,
#                               'driver': 'nico-hulkenberg',
#                               'stops': 2},
#                              {'avg_time_change': -0.21210416666666662,
#                               'driver': 'oscar-piastri',
#                               'stops': 2},
#                              {'avg_time_change': -0.1924893617021279,
#                               'driver': 'pierre-gasly',
#                               'stops': 2},
#                              {'avg_time_change': -0.029339999999999974,
#                               'driver': 'sergio-perez',
#                               'stops': 1},
#                              {'avg_time_change': -0.11722448979591836,
#                               'driver': 'valtteri-bottas',
#                               'stops': 1},
#                              {'avg_time_change': -0.13202777777777777,
#                               'driver': 'esteban-ocon',
#                               'stops': 1}],
#  '2023 Japanese Grand Prix': [{'avg_time_change': -0.29173913043478295,
#                                'driver': 'carlos-sainz-jr',
#                                'stops': 2},
#                               {'avg_time_change': -0.33247826086956545,
#                                'driver': 'charles-leclerc',
#                                'stops': 2},
#                               {'avg_time_change': -0.7672727272727251,
#                                'driver': 'alexander-albon',
#                                'stops': 2},
#                               {'avg_time_change': -0.5109361702127662,
#                                'driver': 'fernando-alonso',
#                                'stops': 2},
#                               {'avg_time_change': -0.20077083333333276,
#                                'driver': 'george-russell',
#                                'stops': 1},
#                               {'avg_time_change': -0.27600000000000074,
#                                'driver': 'guanyu-zhou',
#                                'stops': 3},
#                               {'avg_time_change': -0.22784444444444477,
#                                'driver': 'kevin-magnussen',
#                                'stops': 2},
#                               {'avg_time_change': -0.5243124999999997,
#                                'driver': 'lance-stroll',
#                                'stops': 1},
#                               {'avg_time_change': -0.2089777777777777,
#                                'driver': 'lando-norris',
#                                'stops': 2},
#                               {'avg_time_change': -0.33417391304347766,
#                                'driver': 'lewis-hamilton',
#                                'stops': 2},
#                               {'avg_time_change': -0.30826666666666697,
#                                'driver': 'liam-lawson',
#                                'stops': 2},
#                               {'avg_time_change': -0.07628571428571311,
#                                'driver': 'logan-sargeant',
#                                'stops': 3},
#                               {'avg_time_change': -0.23931111111111028,
#                                'driver': 'max-verstappen',
#                                'stops': 2},
#                               {'avg_time_change': -0.591093023255814,
#                                'driver': 'nico-hulkenberg',
#                                'stops': 3},
#                               {'avg_time_change': -0.3159375000000004,
#                                'driver': 'oscar-piastri',
#                                'stops': 2},
#                               {'avg_time_change': -0.5203555555555558,
#                                'driver': 'pierre-gasly',
#                                'stops': 2},
#                               {'avg_time_change': -0.11387500000000017,
#                                'driver': 'sergio-perez',
#                                'stops': 4},
#                               {'avg_time_change': 0.0,
#                                'driver': 'valtteri-bottas',
#                                'stops': 2},
#                               {'avg_time_change': -0.44739130434782576,
#                                'driver': 'yuki-tsunoda',
#                                'stops': 2},
#                               {'avg_time_change': -0.3284255319148935,
#                                'driver': 'esteban-ocon',
#                                'stops': 2}],
#  '2023 Las Vegas Grand Prix': [{'avg_time_change': 0.22814634146341461,
#                                 'driver': 'carlos-sainz-jr',
#                                 'stops': 2},
#                                {'avg_time_change': 0.08271794871794906,
#                                 'driver': 'charles-leclerc',
#                                 'stops': 1},
#                                {'avg_time_change': -0.0628749999999993,
#                                 'driver': 'alexander-albon',
#                                 'stops': 1},
#                                {'avg_time_change': 0.0487999999999996,
#                                 'driver': 'daniel-ricciardo',
#                                 'stops': 1},
#                                {'avg_time_change': 0.20943902439024398,
#                                 'driver': 'fernando-alonso',
#                                 'stops': 2},
#                                {'avg_time_change': 0.034769230769231,
#                                 'driver': 'george-russell',
#                                 'stops': 2},
#                                {'avg_time_change': 0.09537209302325612,
#                                 'driver': 'guanyu-zhou',
#                                 'stops': 1},
#                                {'avg_time_change': -0.1688500000000001,
#                                 'driver': 'kevin-magnussen',
#                                 'stops': 2},
#                                {'avg_time_change': 0.04345238095238136,
#                                 'driver': 'lance-stroll',
#                                 'stops': 2},
#                                {'avg_time_change': 0.0,
#                                 'driver': 'lando-norris',
#                                 'stops': 0},
#                                {'avg_time_change': 0.038609756097560934,
#                                 'driver': 'lewis-hamilton',
#                                 'stops': 2},
#                                {'avg_time_change': -0.07235000000000014,
#                                 'driver': 'logan-sargeant',
#                                 'stops': 1},
#                                {'avg_time_change': -0.0316923076923078,
#                                 'driver': 'max-verstappen',
#                                 'stops': 2},
#                                {'avg_time_change': -0.30463888888888924,
#                                 'driver': 'nico-hulkenberg',
#                                 'stops': 2},
#                                {'avg_time_change': -0.06749999999999971,
#                                 'driver': 'oscar-piastri',
#                                 'stops': 2},
#                                {'avg_time_change': -0.1327499999999997,
#                                 'driver': 'pierre-gasly',
#                                 'stops': 1},
#                                {'avg_time_change': 0.08111904761904754,
#                                 'driver': 'sergio-perez',
#                                 'stops': 2},
#                                {'avg_time_change': -0.2989090909090906,
#                                 'driver': 'valtteri-bottas',
#                                 'stops': 2},
#                                {'avg_time_change': 0.04594444444444474,
#                                 'driver': 'yuki-tsunoda',
#                                 'stops': 2},
#                                {'avg_time_change': -0.24824390243902364,
#                                 'driver': 'esteban-ocon',
#                                 'stops': 1}],
#  '2023 Mexico City Grand Prix': [{'avg_time_change': 0.011523809523809735,
#                                   'driver': 'carlos-sainz-jr',
#                                   'stops': 2},
#                                  {'avg_time_change': 0.04596923076923054,
#                                   'driver': 'charles-leclerc',
#                                   'stops': 2},
#                                  {'avg_time_change': 0.023484375000000002,
#                                   'driver': 'alexander-albon',
#                                   'stops': 2},
#                                  {'avg_time_change': -0.009253968253967777,
#                                   'driver': 'daniel-ricciardo',
#                                   'stops': 2},
#                                  {'avg_time_change': -0.5278684210526315,
#                                   'driver': 'fernando-alonso',
#                                   'stops': 2},
#                                  {'avg_time_change': -0.07172580645161272,
#                                   'driver': 'george-russell',
#                                   'stops': 2},
#                                  {'avg_time_change': -0.034999999999999795,
#                                   'driver': 'guanyu-zhou',
#                                   'stops': 2},
#                                  {'avg_time_change': -0.18385185185185232,
#                                   'driver': 'kevin-magnussen',
#                                   'stops': 1},
#                                  {'avg_time_change': -0.15633928571428563,
#                                   'driver': 'lance-stroll',
#                                   'stops': 2},
#                                  {'avg_time_change': 0.01417741935483856,
#                                   'driver': 'lando-norris',
#                                   'stops': 3},
#                                  {'avg_time_change': 0.053380952380952376,
#                                   'driver': 'lewis-hamilton',
#                                   'stops': 2},
#                                  {'avg_time_change': -0.21762295081967176,
#                                   'driver': 'logan-sargeant',
#                                   'stops': 2},
#                                  {'avg_time_change': -0.03938095238095252,
#                                   'driver': 'max-verstappen',
#                                   'stops': 3},
#                                  {'avg_time_change': -0.13387096774193566,
#                                   'driver': 'nico-hulkenberg',
#                                   'stops': 2},
#                                  {'avg_time_change': -0.04616129032258079,
#                                   'driver': 'oscar-piastri',
#                                   'stops': 2},
#                                  {'avg_time_change': -0.023451612903225703,
#                                   'driver': 'pierre-gasly',
#                                   'stops': 2},
#                                  {'avg_time_change': 0.0,
#                                   'driver': 'sergio-perez',
#                                   'stops': 0},
#                                  {'avg_time_change': -0.1035312500000003,
#                                   'driver': 'valtteri-bottas',
#                                   'stops': 2},
#                                  {'avg_time_change': -0.16564999999999988,
#                                   'driver': 'yuki-tsunoda',
#                                   'stops': 2},
#                                  {'avg_time_change': -0.09921875000000013,
#                                   'driver': 'esteban-ocon',
#                                   'stops': 1}],
#  '2023 Miami Grand Prix': [{'avg_time_change': 0.029888888888888968,
#                             'driver': 'carlos-sainz-jr',
#                             'stops': 1},
#                            {'avg_time_change': 0.07992592592592623,
#                             'driver': 'charles-leclerc',
#                             'stops': 1},
#                            {'avg_time_change': -0.22637037037037044,
#                             'driver': 'alexander-albon',
#                             'stops': 1},
#                            {'avg_time_change': 0.0063148148148149666,
#                             'driver': 'fernando-alonso',
#                             'stops': 1},
# ...
#                                    {'avg_time_change': 0.10679999999999837,
#                                     'driver': 'lance-stroll',
#                                     'stops': 0},
#                                    {'avg_time_change': -0.13617777777777745,
#                                     'driver': 'lando-norris',
#                                     'stops': 1},
#                                    {'avg_time_change': 0.07877777777777813,
#                                     'driver': 'lewis-hamilton',
#                                     'stops': 1},
#                                    {'avg_time_change': 0.20733333333333362,
#                                     'driver': 'logan-sargeant',
#                                     'stops': 1},
#                                    {'avg_time_change': 0.10808510638297869,
#                                     'driver': 'max-verstappen',
#                                     'stops': 1},
#                                    {'avg_time_change': 0.1904444444444446,
#                                     'driver': 'nico-hulkenberg',
#                                     'stops': 1},
#                                    {'avg_time_change': 0.04042553191489343,
#                                     'driver': 'oscar-piastri',
#                                     'stops': 1},
#                                    {'avg_time_change': 0.0,
#                                     'driver': 'pierre-gasly',
#                                     'stops': 0},
#                                    {'avg_time_change': 0.13944680851063804,
#                                     'driver': 'sergio-perez',
#                                     'stops': 1},
#                                    {'avg_time_change': 0.11258139534883707,
#                                     'driver': 'valtteri-bottas',
#                                     'stops': 2},
#                                    {'avg_time_change': 0.270695652173913,
#                                     'driver': 'yuki-tsunoda',
#                                     'stops': 1},
#                                    {'avg_time_change': 0.2873043478260868,
#                                     'driver': 'esteban-ocon',
#                                     'stops': 1}],
#  '2024 Singapore Grand Prix': [{'avg_time_change': -0.16774999999999995,
#                                 'driver': 'carlos-sainz-jr',
#                                 'stops': 1},
#                                {'avg_time_change': -0.1579833333333333,
#                                 'driver': 'charles-leclerc',
#                                 'stops': 1},
#                                {'avg_time_change': -0.6473333333333322,
#                                 'driver': 'alexander-albon',
#                                 'stops': 1},
#                                {'avg_time_change': -0.7255714285714284,
#                                 'driver': 'daniel-ricciardo',
#                                 'stops': 3},
#                                {'avg_time_change': -0.04836206896551711,
#                                 'driver': 'fernando-alonso',
#                                 'stops': 1},
#                                {'avg_time_change': -0.10301694915254242,
#                                 'driver': 'franco-colapinto',
#                                 'stops': 1},
#                                {'avg_time_change': -0.06785245901639361,
#                                 'driver': 'george-russell',
#                                 'stops': 1},
#                                {'avg_time_change': -0.13293220338983056,
#                                 'driver': 'guanyu-zhou',
#                                 'stops': 1},
#                                {'avg_time_change': -0.2535882352941175,
#                                 'driver': 'kevin-magnussen',
#                                 'stops': 2},
#                                {'avg_time_change': -0.13994915254237272,
#                                 'driver': 'lance-stroll',
#                                 'stops': 1},
#                                {'avg_time_change': -0.12355737704917996,
#                                 'driver': 'lando-norris',
#                                 'stops': 1},
#                                {'avg_time_change': -0.09263934426229502,
#                                 'driver': 'lewis-hamilton',
#                                 'stops': 1},
#                                {'avg_time_change': -0.1098852459016394,
#                                 'driver': 'max-verstappen',
#                                 'stops': 1},
#                                {'avg_time_change': -0.15725423728813545,
#                                 'driver': 'nico-hulkenberg',
#                                 'stops': 1},
#                                {'avg_time_change': -0.12858333333333338,
#                                 'driver': 'oscar-piastri',
#                                 'stops': 1},
#                                {'avg_time_change': -0.058655172413793366,
#                                 'driver': 'pierre-gasly',
#                                 'stops': 1},
#                                {'avg_time_change': -0.10464406779661029,
#                                 'driver': 'sergio-perez',
#                                 'stops': 1},
#                                {'avg_time_change': -0.11867796610169484,
#                                 'driver': 'valtteri-bottas',
#                                 'stops': 1},
#                                {'avg_time_change': -0.1359661016949151,
#                                 'driver': 'yuki-tsunoda',
#                                 'stops': 1},
#                                {'avg_time_change': -0.042551724137931096,
#                                 'driver': 'esteban-ocon',
#                                 'stops': 1}],
#  '2024 Spanish Grand Prix': [{'avg_time_change': -0.05099999999999987,
#                               'driver': 'carlos-sainz-jr',
#                               'stops': 2},
#                              {'avg_time_change': -0.08512903225806438,
#                               'driver': 'charles-leclerc',
#                               'stops': 2},
#                              {'avg_time_change': -0.19899999999999976,
#                               'driver': 'alexander-albon',
#                               'stops': 2},
#                              {'avg_time_change': -0.09945901639344251,
#                               'driver': 'daniel-ricciardo',
#                               'stops': 2},
#                              {'avg_time_change': -0.11659016393442591,
#                               'driver': 'fernando-alonso',
#                               'stops': 2},
#                              {'avg_time_change': -0.13158064516129034,
#                               'driver': 'george-russell',
#                               'stops': 2},
#                              {'avg_time_change': -0.16877049180327894,
#                               'driver': 'guanyu-zhou',
#                               'stops': 2},
#                              {'avg_time_change': -0.13650819672131145,
#                               'driver': 'kevin-magnussen',
#                               'stops': 2},
#                              {'avg_time_change': -0.20291803278688525,
#                               'driver': 'lance-stroll',
#                               'stops': 2},
#                              {'avg_time_change': -0.11469354838709685,
#                               'driver': 'lando-norris',
#                               'stops': 2},
#                              {'avg_time_change': -0.07880645161290338,
#                               'driver': 'lewis-hamilton',
#                               'stops': 2},
#                              {'avg_time_change': -0.21020000000000014,
#                               'driver': 'logan-sargeant',
#                               'stops': 2},
#                              {'avg_time_change': -0.11555555555555558,
#                               'driver': 'max-verstappen',
#                               'stops': 2},
#                              {'avg_time_change': -0.04940322580645165,
#                               'driver': 'nico-hulkenberg',
#                               'stops': 2},
#                              {'avg_time_change': -0.06809677419354807,
#                               'driver': 'oscar-piastri',
#                               'stops': 2},
#                              {'avg_time_change': -0.07419354838709645,
#                               'driver': 'pierre-gasly',
#                               'stops': 2},
#                              {'avg_time_change': -0.24567796610169476,
#                               'driver': 'sergio-perez',
#                               'stops': 3},
#                              {'avg_time_change': -0.1611967213114754,
#                               'driver': 'valtteri-bottas',
#                               'stops': 2},
#                              {'avg_time_change': -0.23061016949152532,
#                               'driver': 'yuki-tsunoda',
#                               'stops': 3},
#                              {'avg_time_change': -0.05138709677419343,
#                               'driver': 'esteban-ocon',
#                               'stops': 2}],
#  '2024 São Paulo Grand Prix': [{'avg_time_change': 0.2711034482758619,
#                                 'driver': 'carlos-sainz-jr',
#                                 'stops': 2},
#                                {'avg_time_change': -0.10974545454545405,
#                                 'driver': 'charles-leclerc',
#                                 'stops': 2},
#                                {'avg_time_change': 0.12514285714285706,
#                                 'driver': 'fernando-alonso',
#                                 'stops': 2},
#                                {'avg_time_change': -0.09507407407407381,
#                                 'driver': 'franco-colapinto',
#                                 'stops': 2},
#                                {'avg_time_change': -0.20698387096774168,
#                                 'driver': 'george-russell',
#                                 'stops': 2},
#                                {'avg_time_change': 0.13063157894736838,
#                                 'driver': 'guanyu-zhou',
#                                 'stops': 4},
#                                {'avg_time_change': -0.013016393442623134,
#                                 'driver': 'lando-norris',
#                                 'stops': 2},
#                                {'avg_time_change': 0.2291249999999998,
#                                 'driver': 'lewis-hamilton',
#                                 'stops': 2},
#                                {'avg_time_change': 0.07400000000000002,
#                                 'driver': 'liam-lawson',
#                                 'stops': 2},
#                                {'avg_time_change': 0.11441666666666706,
#                                 'driver': 'max-verstappen',
#                                 'stops': 1},
#                                {'avg_time_change': -0.11336000000000013,
#                                 'driver': 'nico-hulkenberg',
#                                 'stops': 3},
#                                {'avg_time_change': -0.08720689655172377,
#                                 'driver': 'oscar-piastri',
#                                 'stops': 2},
#                                {'avg_time_change': -0.1260833333333333,
#                                 'driver': 'pierre-gasly',
#                                 'stops': 1},
#                                {'avg_time_change': 0.12954385964912257,
#                                 'driver': 'sergio-perez',
#                                 'stops': 2},
#                                {'avg_time_change': -0.011762711864407065,
#                                 'driver': 'valtteri-bottas',
#                                 'stops': 1},
#                                {'avg_time_change': 0.19618644067796615,
#                                 'driver': 'yuki-tsunoda',
#                                 'stops': 2},
#                                {'avg_time_change': 0.16925862068965505,
#                                 'driver': 'esteban-ocon',
#                                 'stops': 1}],
#  '2024 United States Grand Prix': [{'avg_time_change': -0.013627450980392301,
#                                     'driver': 'carlos-sainz-jr',
#                                     'stops': 1},
#                                    {'avg_time_change': -0.04843137254901959,
#                                     'driver': 'charles-leclerc',
#                                     'stops': 1},
#                                    {'avg_time_change': 0.034285714285714135,
#                                     'driver': 'alexander-albon',
#                                     'stops': 2},
#                                    {'avg_time_change': -0.00013725490196116104,
#                                     'driver': 'fernando-alonso',
#                                     'stops': 1},
#                                    {'avg_time_change': 0.13196078431372585,
#                                     'driver': 'franco-colapinto',
#                                     'stops': 1},
#                                    {'avg_time_change': 0.06478000000000009,
#                                     'driver': 'george-russell',
#                                     'stops': 1},
#                                    {'avg_time_change': -0.1552765957446812,
#                                     'driver': 'guanyu-zhou',
#                                     'stops': 2},
#                                    {'avg_time_change': 0.10695918367346938,
#                                     'driver': 'kevin-magnussen',
#                                     'stops': 2},
#                                    {'avg_time_change': 0.1399607843137256,
#                                     'driver': 'lance-stroll',
#                                     'stops': 1},
#                                    {'avg_time_change': 0.041470588235294294,
#                                     'driver': 'lando-norris',
#                                     'stops': 1},
#                                    {'avg_time_change': 0.0,
#                                     'driver': 'lewis-hamilton',
#                                     'stops': 0},
#                                    {'avg_time_change': 0.036490196078431174,
#                                     'driver': 'liam-lawson',
#                                     'stops': 1},
#                                    {'avg_time_change': 0.014803921568627362,
#                                     'driver': 'max-verstappen',
#                                     'stops': 1},
#                                    {'avg_time_change': 0.07613461538461572,
#                                     'driver': 'nico-hulkenberg',
#                                     'stops': 1},
#                                    {'avg_time_change': 0.043098039215686425,
#                                     'driver': 'oscar-piastri',
#                                     'stops': 1},
#                                    {'avg_time_change': 0.12243137254901988,
#                                     'driver': 'pierre-gasly',
#                                     'stops': 1},
#                                    {'avg_time_change': 0.014153846153845961,
#                                     'driver': 'sergio-perez',
#                                     'stops': 1},
#                                    {'avg_time_change': 0.09319999999999964,
#                                     'driver': 'valtteri-bottas',
#                                     'stops': 1},
#                                    {'avg_time_change': -0.03440816326530627,
#                                     'driver': 'yuki-tsunoda',
#                                     'stops': 1},
#                                    {'avg_time_change': -0.0715319148936169,
#                                     'driver': 'esteban-ocon',
#                                     'stops': 2}]}

# %%
bahrain_2023 = total_data["2023 Bahrain Grand Prix"]
pprint.pprint(bahrain_2023)
# Out:
# [{'avg_time_change': -0.10817307692307693,
#   'driver': 'carlos-sainz-jr',
#   'stops': 2},
#  {'avg_time_change': -0.10827777777777767,
#   'driver': 'charles-leclerc',
#   'stops': 2},
#  {'avg_time_change': -0.18495999999999982,
#   'driver': 'alexander-albon',
#   'stops': 3},
#  {'avg_time_change': -0.0683653846153842,
#   'driver': 'fernando-alonso',
#   'stops': 2},
#  {'avg_time_change': -0.13846153846153825,
#   'driver': 'george-russell',
#   'stops': 2},
#  {'avg_time_change': -0.16631250000000009, 'driver': 'guanyu-zhou', 'stops': 3},
#  {'avg_time_change': -0.2817999999999998,
#   'driver': 'kevin-magnussen',
#   'stops': 3},
#  {'avg_time_change': -0.08065384615384566,
#   'driver': 'lance-stroll',
#   'stops': 2},
#  {'avg_time_change': -0.2494186046511633, 'driver': 'lando-norris', 'stops': 6},
#  {'avg_time_change': -0.0969230769230765,
#   'driver': 'lewis-hamilton',
#   'stops': 2},
#  {'avg_time_change': -0.2317551020408165,
#   'driver': 'logan-sargeant',
#   'stops': 3},
#  {'avg_time_change': -0.10915686274509791,
#   'driver': 'max-verstappen',
#   'stops': 2},
#  {'avg_time_change': -0.39948000000000033,
#   'driver': 'nico-hulkenberg',
#   'stops': 3},
#  {'avg_time_change': -0.0271666666666673,
#   'driver': 'oscar-piastri',
#   'stops': 0},
#  {'avg_time_change': -0.20352000000000003,
#   'driver': 'pierre-gasly',
#   'stops': 3},
#  {'avg_time_change': -0.009980769230769609,
#   'driver': 'sergio-perez',
#   'stops': 2},
#  {'avg_time_change': -0.1785769230769231,
#   'driver': 'valtteri-bottas',
#   'stops': 2},
#  {'avg_time_change': -0.16399999999999978,
#   'driver': 'yuki-tsunoda',
#   'stops': 3},
#  {'avg_time_change': -0.2140000000000003, 'driver': 'esteban-ocon', 'stops': 3}]

# %%
default_keys = ['avg_time_change', 'driver', 'stops', 'race']
flattened_data = []

for race, data in total_data.items():
    if data:
        for entry in data:
            normalized_entry = {key: entry.get(key, None) for key in default_keys}
            normalized_entry['race'] = race
            flattened_data.append(normalized_entry)





race_data_df = pd.DataFrame(flattened_data)

print(race_data_df)
# Out:
#      avg_time_change           driver  stops                       race
# 0          -0.108173  carlos-sainz-jr    2.0    2023 Bahrain Grand Prix
# 1          -0.108278  charles-leclerc    2.0    2023 Bahrain Grand Prix
# 2          -0.184960  alexander-albon    3.0    2023 Bahrain Grand Prix
# 3          -0.068365  fernando-alonso    2.0    2023 Bahrain Grand Prix
# 4          -0.138462   george-russell    2.0    2023 Bahrain Grand Prix
# ..               ...              ...    ...                        ...
# 820        -0.126083     pierre-gasly    1.0  2024 São Paulo Grand Prix
# 821         0.129544     sergio-perez    2.0  2024 São Paulo Grand Prix
# 822        -0.011763  valtteri-bottas    1.0  2024 São Paulo Grand Prix
# 823         0.196186     yuki-tsunoda    2.0  2024 São Paulo Grand Prix
# 824         0.169259     esteban-ocon    1.0  2024 São Paulo Grand Prix
#
# [825 rows x 4 columns]

# %%
race_data_df['performance'] = 1 /(race_data_df['avg_time_change'].abs() * race_data_df['stops'])
X = race_data_df[['avg_time_change', 'stops']]
y = race_data_df['performance']
race_data_df = race_data_df.dropna()

# %%
print(race_data_df.isnull().sum())
# Out:
# avg_time_change    0
# driver             0
# stops              0
# race               0
# performance        0
# dtype: int64

# %%
params = {
    'objective': 'reg:squarederror',
    'eval_metric': 'rmse',
    'eta': 0.1,
    'max_depth': 3
}
#Some are infinity so take that into account.
race_data_df['performance'].replace([float('inf'), float('-inf')], np.nan, inplace=True)
race_data_df.dropna(subset=['performance'], inplace=True)

xgb_model = xg.train(params, xg.DMatrix(race_data_df[['avg_time_change', 'stops']], label=race_data_df['performance']), num_boost_round=100)

race_data_df['predicted_efficiency'] = xgb_model.predict(xg.DMatrix(race_data_df[['avg_time_change', 'stops']]))

race_data_df['rank'] = race_data_df['predicted_efficiency'].rank(ascending=False)


sorted_df = race_data_df.sort_values(by='rank')
print(sorted_df[['driver', 'race', 'predicted_efficiency', 'rank']])
# Out:
#                driver                           race  predicted_efficiency  \
# 711   carlos-sainz-jr        2024 Italian Grand Prix           3656.013916
# 773   fernando-alonso  2024 United States Grand Prix           3656.013916
# 703    max-verstappen          2024 Dutch Grand Prix           1714.096680
# 36       yuki-tsunoda  2023 Saudi Arabian Grand Prix           1714.096680
# 800       liam-lawson    2024 Mexico City Grand Prix           1508.457520
# ..                ...                            ...                   ...
# 220    lewis-hamilton        2023 Belgian Grand Prix              0.392822
# 753  daniel-ricciardo      2024 Singapore Grand Prix              0.392822
# 482       guanyu-zhou       2024 Japanese Grand Prix              0.238669
# 221    logan-sargeant        2023 Belgian Grand Prix              0.238669
# 212   alexander-albon        2023 Belgian Grand Prix              0.238669
#
#       rank
# 711    1.5
# 773    1.5
# 703    3.5
# 36     3.5
# 800    5.0
# ..     ...
# 220  781.5
# 753  781.5
# 482  784.0
# 221  784.0
# 212  784.0
#
# [785 rows x 4 columns]

# %% [markdown]
# The next step is to average out the rankings across the races for each driver.

# %%
#Calculates and stores the driver tyre efficiency.
driver_efficiency = race_data_df.groupby('driver')['predicted_efficiency'].mean().reset_index()
driver_efficiency.rename(columns={'predicted_efficiency': 'efficiency_score'}, inplace=True)
scaler = MinMaxScaler(feature_range=(1.0, 1.09))
driver_efficiency['efficiency_score'] = scaler.fit_transform(driver_efficiency[['efficiency_score']])
driver_efficiency['efficiency_score'] = 2.09 - driver_efficiency['efficiency_score']
print(driver_efficiency)
# %store driver_efficiency
# Out:
#               driver  efficiency_score
# 0    alexander-albon          1.089638
# 1    carlos-sainz-jr          1.039664
# 2    charles-leclerc          1.085786
# 3   daniel-ricciardo          1.087017
# 4       esteban-ocon          1.088308
# 5    fernando-alonso          1.045747
# 6   franco-colapinto          1.087274
# 7     george-russell          1.089411
# 8        guanyu-zhou          1.090000
# 9    kevin-magnussen          1.089999
# 10      lance-stroll          1.086351
# 11      lando-norris          1.086976
# 12    lewis-hamilton          1.087382
# 13       liam-lawson          1.000000
# 14    logan-sargeant          1.089939
# 15    max-verstappen          1.067213
# 16   nico-hulkenberg          1.087153
# 17     oscar-piastri          1.086413
# 18      pierre-gasly          1.088400
# 19      sergio-perez          1.088617
# 20   valtteri-bottas          1.088266
# 21      yuki-tsunoda          1.068548
# Stored 'driver_efficiency' (DataFrame)
# /usr/lib/python3/dist-packages/IPython/extensions/storemagic.py:229: UserWarning: using autorestore/driver_efficiency requires you to install the `pickleshare` library.
#   db[ 'autorestore/' + arg ] = obj

# %% [markdown]
# Some of these findings did spark some concern as it denotes that Liam Lawson is incredible at tyre management. This is likely due to the lack of data as he only competed in a few races within the dataset. Other than this outlier the rest of the values seem acceptable and so as long as the results are skewed these will be used.

# %%
driver_efficiency.to_csv('driver_efficiency.csv', index=False)
